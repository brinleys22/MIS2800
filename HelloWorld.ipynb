# %% [markdown]
# <a href="https://colab.research.google.com/github/brinleys22/MIS2800/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello World")
# Out:
# hello World

# %%
print ("MIS is best")
# Out:
# MIS is best
